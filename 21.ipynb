# %% [markdown]
# ## Army all over the world

# %% [markdown]
# ### members names:
# May Ashkenazi
#
# Barak Wizberger
#
# Eden Journo

# %% [markdown]
# ### Data source:
# https://www.kaggle.com/datasets/prasertk/military-power-by-country-2022
#
# #### Our GitHub: https://github.com/mayas9/my-project

# %%
url= 'https://github.com/mayas9/my-project/raw/main/global%20firepower%202022%20wide.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from IPython.core.display import Image
import matplotlib.colors as mcolors

# %% [markdown]
# <img src='https://raw.githubusercontent.com/mayas9/my-project/main/army%20pic.jpg' width=700 height=700
# align=center />

# %%
army= pd.read_csv(url)

# %%
army.head()
# Out:
#        country      Mainland country_code  Active Personnel  \
# 0  Afghanistan          Asia          AFG                 0
# 1      Albania        Europe          ALB              8000
# 2      Algeria        Africa          ALG            130000
# 3       Angola        Africa          ANG            107000
# 4    Argentina  S/N/C Amirca          ARG             83000
#
#    Aircraft Carriers  Armored Vehicles  Attack Helicopters  \
# 0                  0               530                   0
# 1                  0                76                   0
# 2                  0              6461                  45
# 3                  0              1210                  15
# 4                  0               800                   0
#
#    Available Manpower  Coastline Coverage  Corvettes  ...  Square Land Area  \
# 0            14611901                   0          0  ...            652230
# 1             1513309                 362          0  ...             28748
# ...

# %%
army.columns = army.columns.str.replace(' ','_')

# %% [markdown]
# ## <div dir="rtl">בדיקת ערכים חסרים </div>

# %%
army.isnull().sum()
# Out:
# country                      0
# Mainland                     0
# country_code                 0
# Active_Personnel             0
# Aircraft_Carriers            0
# Armored_Vehicles             0
# Attack_Helicopters           0
# Available_Manpower           0
# Coastline_Coverage           0
# Corvettes                    0
# Dedicated_Attack             0
# Defense_Budget               0
# Destroyers                   0
# External_Debt                0
# Fighters/Interceptors        0
# Fit-for-Service              0
# Foreign_Exchange/Gold        0
# Frigates                     0
# Helicopter_Carriers          0
# Helicopters                  0
# Labor_Force                  0
# Merchant_Marine_Fleet        0
# Mine_Warfare                 0
# Navy_Ships                   0
# Oil_Consumption              0
# Oil_Production               0
# Oil_Proven_Reserves          0
# Paramilitary                 0
# Patrol_Vessels               0
# Ports_/_Trade_Terminals      0
# ...

# %% [markdown]
# #### <div dir="rtl">לאחר מעבר על הנתונים זיהינו שבעמודת "נושאות המטוסים" יש חריגה במדינה סרי לנקה. המחשנו זאת ע"י גרף (בוקספלוט) בו ניתן לראות רעש מובהק, אותו ננקה ע"י החלפת הערך ל-0

# %%
sns.boxplot(data= army, y= 'Aircraft_Carriers');

# %%
army.loc[(army.country== 'Sri Lanka'),'Aircraft_Carriers']= 0

# %%
max_def_budget=army[['country','Defense_Budget']].nlargest(10, 'Defense_Budget')

# %%
army['perc_def_budget']= army['Defense_Budget']/army['Country_Budget']*100
max_prec= army.nlargest(10, 'perc_def_budget')
min_prec= army.nsmallest(10, 'perc_def_budget')#לא השתמשנו?

# %% [markdown]
# ### <div dir="rtl">ניתן לראות את רשימת 10 המדינות עם השקעת האחוז הגבוה ביותר של תקציב ביטחון מתוך תקציב המדינה :

# %%
sns.barplot(data= max_prec, y= 'perc_def_budget', x= 'country') 
plt.xticks(rotation=70);

# %%
fig, axes = plt.subplots(figsize=(10, 5), ncols=2)
sns.barplot(ax= axes[0], data= max_prec, y= 'perc_def_budget', x= 'country').set(title= 'ןוחטיבה ביצקת זוחא') 
sns.barplot(ax= axes[1],data= max_def_budget, y= 'Defense_Budget', x= 'country').set(title= '      =דראילימ 100                 ןוחטיבה ביצקת') 
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=70);
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=70);
axes[0].set_xlabel('');
axes[1].set_xlabel('');

# %% [markdown]
# #### <div dir="rtl">אין חפיפה מושלמת בין המדינות בכל גרף.</div>
# #### <div dir="rtl"> ניתן להבחין כי המדינות שמשקיעות את אחוז תקציב המדינה הגבוה ביותר </div>
# #### <div dir="rtl">רובן הן מדינות אשר המצב הבטחוני בהן בעייתי כמו למשל </div>
# #### <div dir="rtl">ישראל: איום חיצוני ופנימי</div>
# #### <div dir="rtl">לוב\סוריה: מלחמות אזרחים</div>
# #### <div dir="rtl">רוסיה: במלחמה כעת</div>
# #### <div dir="rtl">ארה"ב: מעורבת במלחמות וסכסוכים חיצוניים לעתים קרובות</div>
# #### <div dir="rtl">צפון קוריאה: מדינה דיקטטורית מאיימת</div>
# ## <div dir="rtl"><span style='background : yellow' > מסקנה 1:
# ## <div dir="rtl">מדינות כמו אוסטרליה ואיחוד האמירויות שאינן נתונות במצב איום או מלחמה יכולות להשקיע פחות בתקציב הביטחון ולהפנות משאבים לחינוך וכו</div>

# %% [markdown]
# ## <center><span style='background :pink'>רוסיה</span></center>
# ## <center>|</center>
# ## <center><span style='background :yellow'>אוקראינה</span></center>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/mayas9/army-project/main/russia%20ukraine%20picture.jpeg" width=800 height=800 align=right />

# %%
war= army[(army['country']== 'Russia') | (army['country']== 'Ukraine')|(army['country']== 'Israel')].copy()

# %% [markdown]
# ### <div dir="rtl">רצינו לחקור על המלחמה בין רוסיה לאוקראינה. בחרנו להציג פרמטרים כמותיים שיציגו את יחסי הכוחות בין המדינות בנוסף לצורך "קנה מידה" הוספנו את מדינת ישראל.

# %%
fig,axes= plt.subplots(figsize= (20,10),nrows=2 , ncols= 3 )
sns.barplot(ax= axes[0,0], x= 'country' ,y='Tanks', data= war,palette= 'summer'); 
sns.barplot(ax= axes[0,1], x= 'country' ,y='Total_Aircraft_Strength', data= war,palette= 'cool_r');
sns.barplot(ax= axes[0,2], x= 'country' ,y= 'Navy_Ships', data= war,palette= 'hot_r');
sns.barplot(ax= axes[1,0], x= 'country' ,y='Country_Budget', data= war,palette= 'summer');
sns.barplot(ax= axes[1,1], x= 'country' ,y= 'Active_Personnel', data= war,palette= 'cool_r');
sns.barplot(ax= axes[1,2], x= 'country' ,y= 'Attack_Helicopters', data= war,palette= 'hot_r');

# %% [markdown]
# ### <div dir="rtl">מהגרפים לעיל, ניתן לראות כי בכלל הפרמטרים שנבדקו, רוסיה ביתרון חד משעמי לעומת ישראל ואוקראינה
# [מצב מלחמה עדכני רוסיה-אוקראינה](https://makospecial.co.il/ukrainewar)

# %%
war['perc_active_available']= army['Active_Personnel']/army['Available_Manpower']*100
war['perc_aircraft_area']= army['Total_Aircraft_Strength']/army['Square_Land_Area']*100

# %% [markdown]
# יצרנו עמודות של יחס בין כמות חיילים פעילים לבין כמות אנשים שכשירים לשרת בצבא
# בנוסף עמודה של יחס בין כח אווירי ביחס לגודל המדינה

# %% [markdown]
# ### <div dir="rtl"><span style='background :yellow' > :לאחר שהצגנו את הנתונים הכמותיים, כעת נציג נתונים יחסיים באחוזים </span>
# <div dir="rtl">1. יחס בין מספר החיילים לבין מספר אנשים כשירים לשירות
# <div dir="rtl">2. יחס בין עוצמת הכח האווירי לבין שטח המדינה
# 3. יחס בין תקציב המדינה לבין תקציב הביטחון

# %%
fig,axes= plt.subplots(figsize= (15,5) , ncols= 3 )
sns.barplot(ax= axes[0], x= 'country' ,y='perc_active_available', data= war).set(title= "תורישל םירישכ םילייח רפסמ");
sns.barplot(ax= axes[1], x= 'country' ,y='perc_def_budget', data= war, ).set(title= "ןוחטיבה ביצקתל הנידמה ביצקת");
sns.barplot(ax= axes[2], x= 'country' ,y= 'perc_aircraft_area', data= war).set(title= "הנידמה חטשל יריווא חוכ");

# %% [markdown]
# #### <div dir="rtl">מהניתוח שערכנו ניתן לראות כי רוסיה ביחס לישראל ואוקראינה אכן בעלת הכח הצבאי ההרב ביותר מבחינה כמותית, מה שמאשש את יתרונה במלחמה.  עם זאת ניתן להבחין כי ישראל משקיעה את האחוז הגבוה ביותר בהשקעה כספית, הקצאת כח אדם ומשאבים צבאיים.

# %% [markdown]
# ## <div dir="rtl"> <span style='background :yellow' > מסקנה 2: </span>

# %% [markdown]
# ###  <div dir="rtl">  במידה ואוקראינה הייתה מתנהלת כמו ישראל ומגדילה את משאביה ביטחוניים כמו הגדלת צי המטוסים ויותר משרתים פעילים, אולי מצבה היה אחר מהקיים בימנו אנו.

# %%
features= ['External_Debt','Country_Budget','Defense_Budget','Active_Personnel','Attack_Helicopters','Square_Land_Area','Tanks','Total_Aircraft_Strength' ,'Total_Population','Navy_Ships','Shared_Borders']
corrs = army[army.Mainland == 'Europe'][features].corr(method = 'spearman')

plt.figure(figsize=(25,20))  #figure size
sns.heatmap(corrs, cmap='coolwarm', center=0, annot = True);

# %% [markdown]
# ##### <div dir="rtl">השתמשתנו בקורלציית פירסון כי ראינו שהדאטה לא מתנהגת נורמלית ברובה לכן השתמשנו בקורלציה זו

# %% [markdown]
# ##### <div dir="rtl"><span style='background : yellow' > ממפת החום ניתן לראות קורלציה של 0.89 בין כח אווירי לבין תקציב הבטחון

# %% [markdown]
# ####   <div dir="rtl"> כעת נחקור קורלציה זו על יבשת אירופה

# %%
sns.regplot(data= army[army.Mainland == 'Europe'] , y= 'Defense_Budget', x= 'Total_Aircraft_Strength')
# Out:
# <AxesSubplot:xlabel='Total_Aircraft_Strength', ylabel='Defense_Budget'>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/mayas9/army-project/main/airplain11.jpg' width=700 height=700
# align=center />

# %% [markdown]
# #### <div dir="rtl"> לאחר שמצאנו התאמה בין השקעה בתקציב הביטחון לבין השקעה בכח אווירי, נבחן את זה כנגד טנקים וספינות חייל הים במדינות אירופה שאנו מעריכים כמדינות מפותחות

# %%
features= ['Defense_Budget','Tanks','Total_Aircraft_Strength' ,'Navy_Ships']
corrs = army[army.Mainland == 'Europe'][features].corr(method = 'spearman')

plt.figure(figsize=(5,5))  
sns.heatmap(corrs, cmap='coolwarm', center=0, annot = True);

# %%
fig, axes = plt.subplots(figsize=(10, 5), ncols=3)
Europe= army[army.Mainland == 'Europe']
sns.regplot(data= Europe[Europe.Total_Aircraft_Strength<4000] , y= 'Defense_Budget', x= 'Total_Aircraft_Strength',ax= axes[0])
sns.regplot(data= Europe[Europe.Navy_Ships <600] , y= 'Defense_Budget', x= 'Navy_Ships',ax= axes[1], color= 'r')
sns.regplot(data= Europe[Europe.Tanks <12000], y= 'Defense_Budget', x= 'Tanks', ax= axes[2],color='g')
plt.tight_layout()

# %% [markdown]
# ##### <div dir="rtl"> ניתן לראות שמדינות אכן מעדיפות להשקיע יותר בחיל האוויר

# %% [markdown]
# ##  <div dir="rtl"><span style='background :yellow' > :מסקנה 3 </span>

# %% [markdown]
# #### <div dir="rtl">ניתן לראות על פי הגרפים המוצגים , לאחר ניקוי חריגים, כי אכן במדינות אירופה יש קשר חזק בין גודל תקציב הבטחון לבין   השקעה בכח אווירי לעומת השקעה פחותה בטנקים ובספינות

# %% [markdown]
# ## <div dir="rtl">  לסיום ניקח מספר קטגוריות ונבחן ניצחון במידה

# %%
world= army.groupby('Mainland').sum().reset_index().copy()
fig,axes= plt.subplots(figsize= (20,10),nrows=2 , ncols= 3 )
sns.barplot(ax= axes[0,0], x= 'Mainland' ,y='Tanks', data= world,palette= 'pink'); 
sns.barplot(ax= axes[0,1], x= 'Mainland' ,y='Total_Aircraft_Strength', data= world,palette= 'Greens');
sns.barplot(ax= axes[0,2], x= 'Mainland' ,y= 'Navy_Ships', data= world,palette= 'YlOrBr');
sns.barplot(ax= axes[1,0], x= 'Mainland' ,y='Country_Budget', data= world,palette= 'autumn');
sns.barplot(ax= axes[1,1], x= 'Mainland' ,y= 'Active_Personnel', data= world,palette= 'Blues');
sns.barplot(ax= axes[1,2], x= 'Mainland' ,y= 'Attack_Helicopters', data= world,palette= 'Greys');
